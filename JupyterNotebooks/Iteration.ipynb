# %% [markdown]
# # For Loops
#
# for variable in something:
#
#     algorithm

# %%
tup = (0,1,2,3,4)
for i in tup:
    print(i)
# Out:
# 0
# 1
# 2
# 3
# 4

# %% [markdown]
# ![image.png](attachment:image.png)
